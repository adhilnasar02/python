# %%
#3rd element and 3rd element from last of a tuple
tuple = (34,54,12,67,76,84,36)
print("3rd element: ",tuple[2])
print("3rd element from last: ",tuple[-3])
# Out:
# 3rd element:  12
# 3rd element from last:  76

# %%
#accept number from user and generate a tuple and find it's average 
num = input("Enter numbers(comma-seperated): ")
t = tuple(int(x)for x in num.split(","))
average = sum(t) / len(t)
print("Tuple: :", t)
print("Average: ",average)
# Out:
# Enter numbers(comma-seperated):  23,12,54,22
# Tuple: : (23, 12, 54, 22)
# Average:  27.75
