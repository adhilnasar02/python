# %%
# Colors that are in set1 but not in set2
set_1 = set(input("Enter colors for set-1 (comma-separated): ").split(","))
set_2 = set(input("Enter colors for set-2 (comma-separated): ").split(","))
difference = set_1 - set_2
print("Original set-1:", set_1)
print("Original set-2:", set_2)
print("Colors in set-1 not in set-2:", difference)
# Out:
# Enter colors for set-1 (comma-separated):  Green,Violet,Silver,Gold,Red
# Enter colors for set-2 (comma-separated):  Black,Green,Blue,Red,Yellow
# Original set-1: {'Gold', 'Red', 'Green', 'Silver', 'Violet'}
# Original set-2: {'Blue', 'Black', 'Red', 'Green', 'Yellow'}
# Colors in set-1 not in set-2: {'Gold', 'Silver', 'Violet'}

# %%
# All colors from set1 and set2
set_1 = set(input("Enter colors for set-1 (comma-separated): ").split(","))
set_2 = set(input("Enter colors for set-2 (comma-separated): ").split(","))
print("Original set-1:", set_1)
print("Original set-2:", set_2)
print("Colors from set-1 and set-2:")
print(set_1.union(set_2))
# Out:
# Enter colors for set-1 (comma-separated):  Green,Violet,Silver,Gold,Red
# Enter colors for set-2 (comma-separated):   Black,Green,Blue,Red,Yellow
# Original set-1: {'Gold', 'Red', 'Green', 'Silver', 'Violet'}
# Original set-2: {'Blue', ' Black', 'Red', 'Green', 'Yellow'}
# Colors from set-1 and set-2:
# {'Gold', 'Blue', ' Black', 'Green', 'Red', 'Silver', 'Violet', 'Yellow'}
